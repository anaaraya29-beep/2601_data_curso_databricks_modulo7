# %% [markdown]
# ## Recurso de DBDemos
#
# Los notebooks disponibles en `_/resources` son recursos técnicos.
#
# No edites estos notebooks ni intentes ejecutarlos directamente. Estos notebooks cargarán datos o ejecutarán configuraciones. Son llamados indirectamente desde el notebook principal (`%run ./_resources/.....`)
