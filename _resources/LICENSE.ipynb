# %% [markdown]
# ## Licencia

# %% [markdown]
# Copyright (2022) Databricks, Inc.
#
# Esta biblioteca (el "Software") no puede ser utilizada excepto en relación con el uso que el Licenciatario haga de los Servicios de la Plataforma Databricks conforme a un Acuerdo (definido abajo) entre el Licenciatario (definido abajo) y Databricks, Inc. ("Databricks"). La versión de Código Objeto del Software se considerará parte de los Servicios Descargables bajo el Acuerdo, o si el Acuerdo no define Servicios Descargables, Servicios de Suscripción, o si ninguno está definido, entonces el término en dicho Acuerdo que se refiera a los Servicios de Plataforma Databricks aplicables (según se define abajo) será sustituido aquí por “Servicios Descargables”. El uso del Software por parte del Licenciatario debe cumplir en todo momento con cualquier restricción aplicable a los Servicios Descargables y Servicios de Suscripción, en general, y debe usarse de acuerdo con cualquier documentación aplicable. Para evitar dudas, el Software constituye Información Confidencial de Databricks bajo el Acuerdo.
#
# Adicionalmente, y sin perjuicio de cualquier disposición en contrario en el Acuerdo:
# * EL SOFTWARE SE PROPORCIONA "TAL CUAL", SIN GARANTÍA DE NINGÚN TIPO, EXPRESA O IMPLÍCITA, INCLUYENDO PERO NO LIMITADO A LAS GARANTÍAS DE COMERCIABILIDAD, IDONEIDAD PARA UN PROPÓSITO PARTICULAR Y NO INFRACCIÓN. EN NINGÚN CASO LOS AUTORES O TITULARES DE LOS DERECHOS DE AUTOR SERÁN RESPONSABLES POR NINGUNA RECLAMACIÓN, DAÑO U OTRA RESPONSABILIDAD, YA SEA EN UNA ACCIÓN CONTRACTUAL, EXTRACONTRACTUAL O DE OTRO TIPO, QUE SURJA DE, FUERA DE O EN CONEXIÓN CON EL SOFTWARE O EL USO U OTRO TIPO DE ACCIONES EN EL SOFTWARE.
# * puedes ver, hacer copias limitadas y compilar la versión de Código Fuente del Software en una versión de Código Objeto del Software. Para evitar dudas, no puedes crear trabajos derivados del Software (ni realizar ningún cambio en el Código Fuente) a menos que hayas acordado términos separados con Databricks que permitan tales modificaciones (por ejemplo, un acuerdo de contribución de código).
#
# Si no has aceptado un Acuerdo o de otro modo no aceptas estos términos, no puedes usar el Software ni ver, copiar o compilar el Código Fuente del Software.
#
# Esta licencia termina automáticamente al finalizar el Acuerdo o si el Licenciatario incumple estos términos. Además, Databricks puede terminar esta licencia en cualquier momento mediante notificación. Al finalizar, debes eliminar permanentemente el Software y todas las copias del mismo (incluyendo el Código Fuente).
#
# Acuerdo: el acuerdo entre Databricks y el Licenciatario que rige el uso de los Servicios de la Plataforma Databricks, que será, respecto a Databricks, los Términos de Servicio de Databricks ubicados en www.databricks.com/termsofservice, y respecto a Databricks Community Edition, los Términos de Servicio de Community Edition ubicados en www.databricks.com/ce-termsofuse, en cada caso a menos que el Licenciatario haya celebrado un acuerdo escrito separado con Databricks que rija el uso de los Servicios de Plataforma Databricks aplicables.
#
# Servicios de Plataforma Databricks: los servicios de Databricks o los servicios de Databricks Community Edition, según donde se use el Software.
#
# Licenciatario: el usuario del Software, o, si el Software se utiliza en nombre de una empresa, la empresa.
#
# Código Objeto: es la versión del Software producida cuando un intérprete o compilador traduce el Código Fuente en código máquina reconocible y ejecutable.
#
# Código Fuente: la parte legible por humanos del Software.
